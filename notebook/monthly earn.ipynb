# %%
import pandas_datareader as pdr
from pandas_datareader import data

import monthly_returns_heatmap as mrh
my_list = ["NVDA"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["JD"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["NTES"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list=["ACSI","GYLD","DWAT","BCI","GLTR","SIVR","SGOL","KRMA","GURU","EFFE","SCTO","MLPX","MLPA","SDEM","EMFM","CATH","SCIX","SCID","SCIJ","SCIU","DIV","SDIV","SRET","SPFF","EWEM","RCD","RHS","RYE","RSP","RYF","RYH","RGI","RTM","EWRE","RYT","RYU","GHII","EWMC","EWSC","GTO","HFXE","HFXI","HFXJ","GRES","MNA","AGGE","AGGP","QAI","ROOF","VNLA","SGQI","JSMD","TRSK","SPXH","JHMC","JHMS","JHME","JHMF","JHMH","JHMI","JHML","JHMA","JHMM","JHMT","JHMU","JPHY","JPHF","JPEM","JPEH","JPEU","JPGE","JPIH","JPIN","JPUS","JPME","JPSE","JPGB","JPST","INFR","LVHI","LVHD","NUSA","NUAG","NUEM","NUDM","NULV","NUSC","ESGL","ESGF","RWL","RWK","RWJ","RDIV","ALTY","ALD","AXJL","AUSE","AGND","AGZD","AGGY","USDU","HYND","HYZD","BZF","CXSE","CYB","DDWM","CEW","EMCG","EMCB","XSOE","DEM","ELD","DGRE","DGS","HEDJ","EUSC","EUDG","DFE","DXGE","DNL","DRW","DEW","EPI","DOO","DWM","IHDG","DTH","DOL","DIM","DLS","DXJ","DXJF","JHDG","DXJR","DXJS","DFJ","WDTI","GULF","DTN","EPS","DHS","DLN","EZY","DON","EZM","DGRW","DES","EES","DGRS","DTD","EXT","DXPS"]

# %%
import pandas_datareader as pdr
from pandas_datareader import data

import monthly_returns_heatmap as mrh

for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-c7960331e985> in <module>()
#       7     prices = data.get_data_yahoo(var)['Close']
#       8     returns = prices.pct_change()
# ----> 9     mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")
#
# C:\ProgramData\Miniconda2\lib\site-packages\monthly_returns_heatmap\__init__.pyc in plot(returns, title, title_color, title_size, annot_size, figsize, cmap, cbar, square)
#      67          square=False):
#      68
# ---> 69     returns = get(returns)
#      70     returns *= 100
#      71
#
# C:\ProgramData\Miniconda2\lib\site-packages\monthly_returns_heatmap\__init__.pyc in get(returns)
#      52     # order columns by month
#      53     returns = returns[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
# ---> 54                      'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
#      55
# ...
