# %%
import pandas_datareader as pdr
from pandas_datareader import data
prices = data.get_data_yahoo("SPY")

# %%
import ytd

# %%
import pandas as pd

# %%
nasdaq = pd.read_csv("NASDAQ.csv")

# %%
nasdaq
# Out:
#      Symbol                                    Name LastSale MarketCap  \
# 0       PIH  1347 Property Insurance Holdings, Inc.     7.55   $44.97M
# 1      TURN                180 Degree Capital Corp.      1.7   $52.91M
# 2      FLWS                 1-800 FLOWERS.COM, Inc.      9.7  $629.33M
# 3      FCCY           1st Constitution Bancorp (NJ)     18.2  $146.86M
# 4      SRCE                  1st Source Corporation    48.46    $1.26B
# 5      VNET                    21Vianet Group, Inc.     6.01  $676.13M
# 6      TWOU                                2U, Inc.    52.92    $2.54B
# 7      JOBS                             51job, Inc.    59.55    $3.66B
# 8      CAFD              8point3 Energy Partners LP    14.59    $1.15B
# 9      EGHT                                 8x8 Inc       13    $1.19B
# 10     AVHI                         A V Homes, Inc.    16.45   $369.4M
# 11     SHLM                       A. Schulman, Inc.     33.6  $990.01M
# ...
