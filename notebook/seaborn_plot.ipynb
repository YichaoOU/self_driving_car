# %%
import seaborn as sns
sns.set(style="whitegrid", palette="pastel", color_codes=True)

# Load the example tips dataset
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
import pandas as pd
result = pd.read_csv("enrichment_greedy.csv")

# %%
result
# Out:
#             Type    Values       Class
# 0    Sensitivity  0.840200  enrichment
# 1    Sensitivity  0.680500  enrichment
# 2    Sensitivity  0.756900  enrichment
# 3    Sensitivity  0.447800  enrichment
# 4    Sensitivity  0.836800  enrichment
# 5    Sensitivity  0.646800  enrichment
# 6    Sensitivity  0.838300  enrichment
# 7    Sensitivity  0.705000  enrichment
# 8    Sensitivity  0.568756  enrichment
# 9    Sensitivity  0.712335  enrichment
# 10   Sensitivity  0.590800  enrichment
# 11   Sensitivity  0.515600  enrichment
# 12   Sensitivity  0.845200  enrichment
# 13   Sensitivity  0.501300  enrichment
# 14   Sensitivity  0.591200  enrichment
# 15   Sensitivity  0.668500  enrichment
# 16   Sensitivity  0.695600  enrichment
# 17   Sensitivity  0.673800  enrichment
# 18   Sensitivity  0.279500  enrichment
# 19   Sensitivity  0.523000  enrichment
# 20   Sensitivity  0.365400  enrichment
# 21   Sensitivity  0.628200  enrichment
# 22   Sensitivity  0.492900  enrichment
# ...

# %%
result = pd.read_csv("enrichment_greedy.csv")
sns.violinplot(x="Type", y="Values", hue="Class", data=result, split=True,
               inner="quart", cut  =0,palette={"greedy": "b", "enrichment": "y"})
sns.despine(left=True)
from matplotlib import pyplot
sns.plt.show()

# %%
result = pd.read_csv("Num_motif_enrich_greedy.csv")
sns.violinplot(x="Type", y="Values", hue="Class", data=result, split=True,
               inner="quart", cut  =0,palette={"greedy": "b", "enrichment": "y"})
sns.despine(left=True)
sns.plt.show()
