# %%
import pandas_datareader as pdr

# %%
pdr.get_data_yahoo('AAPL')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04   30.490000   30.642857   30.340000   30.572857   27.505054
# 2010-01-05   30.657143   30.798571   30.464285   30.625713   27.552608
# 2010-01-06   30.625713   30.747143   30.107143   30.138571   27.114347
# 2010-01-07   30.250000   30.285715   29.864286   30.082857   27.064222
# 2010-01-08   30.042856   30.285715   29.865715   30.282858   27.244156
# 2010-01-11   30.400000   30.428572   29.778572   30.015715   27.003820
# 2010-01-12   29.884285   29.967142   29.488571   29.674286   26.696650
# 2010-01-13   29.695715   30.132856   29.157143   30.092857   27.073221
# 2010-01-14   30.015715   30.065714   29.860001   29.918571   26.916422
# 2010-01-15   30.132856   30.228571   29.410000   29.418571   26.466595
# 2010-01-19   29.761429   30.741428   29.605715   30.719999   27.637430
# 2010-01-20   30.701429   30.792856   29.928572   30.247143   27.212029
# ...

# %%
from pandas_datareader import data
prices = data.get_data_google("SPY")['Close']
returns = prices.pct_change()
# import monthly_returns_heatmap as mrh

# returns.plot_monthly_returns_heatmap()

# %%
from pandas_datareader import data
prices = data.get_data_yahoo("VTI")['Close']
returns = prices.pct_change()
import monthly_returns_heatmap as mrh

mrh.plot(returns,figsize=(10,6))

# %%
prices = data.get_data_google("VTI")['Close']
returns = prices.pct_change()
mrh.plot(returns,figsize=(10,6))

# %%
prices = data.get_data_google("VYM")['Close']
returns = prices.pct_change()
mrh.plot(returns,figsize=(10,6))

# %%
prices = data.get_data_google("VDE")['Close']
returns = prices.pct_change()
mrh.plot(returns,figsize=(10,6))

# %%
var = "VFH"
prices = data.get_data_google(var)['Close']
returns = prices.pct_change()
mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["VFH","VDE","VTI","VOO","VYM","VCLT","VNQ","VWO","SKT","KR"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["CSTM","CELH","CLF","NXEO","NLY","CHK","WPC","BP","SNY","JD","BIDU","BABA","TCEHY"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["AMZN"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["AAPL"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["ZG"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
my_list = ["FMSA"]
for var in my_list:
    prices = data.get_data_yahoo(var)['Close']
    returns = prices.pct_change()
    mrh.plot(returns,figsize=(10,6),title=var+" Monthly Returns (%)")

# %%
from urllib import urlopen
from lxml.html import parse

'''
Returns a tuple (Sector, Indistry)
Usage: GFinSectorIndustry('IBM')
'''
def GFinSectorIndustry(name):
  tree = parse(urlopen('http://www.google.com/finance?&q='+name))
  return tree.xpath("//a[@id='sector']")[0].text, tree.xpath("//a[@id='sector']")[0].getnext().text

# %%
GFinSectorIndustry('IBM')
# Out:
# ('Technology', 'IT Services & Consulting - NEC')
